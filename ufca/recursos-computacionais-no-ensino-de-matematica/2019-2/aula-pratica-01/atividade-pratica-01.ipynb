# %% [markdown]
# # Padrões pedagógicos usando Jupyter

# %% [markdown]
# <br>

# %% [markdown]
# O objetivo desta atividade é exercitar a composição de blocos de nota Jupyter usando apenas células de texto.

# %% [markdown]
# ## Título do padrão escolhido

# %% [markdown]
# _Agora, você deverá construir o restante do documento conforme solicitado anteriormente._

# %% [markdown]
# ## Extensões

# %% [markdown]
# ## Saiba mais

# %% [markdown]
# - Você pode (deve!) sempre incluir vídeos do Youtube para enriquecer seus blocos de nota. Por exemplo, se você está interessado em exibir um vídeo que assistiu no endereço __[https://www.youtube.com/watch?v=SyCX2YfCQAM](https://www.youtube.com/watch?v=SyCX2YfCQAM)__, basta usar o identificador no código abaixo `SyCX2YfCQAM`:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='SyCX2YfCQAM',width=600,height=300)
